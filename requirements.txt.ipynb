# %%
import pandas
import numpy
import matplotlib
import seaborn
import sklearn
import imblearn
import xgboost
import pyodbc
import sqlalchemy
import mlflow
import lime
import joblib

print("All required packages are available.")
# Out:
# All required packages are available.

# %%
# saved the cleaned_featured_churn_dataset
df.to_csv("requirement.txt", index=False)
df.to_csv(r"C:\Users\Surya\OneDrive\Desktop\CUSTOMER CHURN PROJECT\requirement.txt",index=False)

print("requirement.txt saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # saved the cleaned_featured_churn_dataset
# ----> 2 df.to_csv("requirement.txt", index=False)
#       3 df.to_csv(r"C:\Users\Surya\OneDrive\Desktop\CUSTOMER CHURN PROJECT\requirement.txt",index=False)
#       4
#       5 print("requirement.txt saved successfully!")
#
# NameError: name 'df' is not defined
